# %%
import os
from openai import OpenAI
from dotenv import load_dotenv

load_dotenv()

API_KEY = os.getenv("OPENAI_API_KEY","").strip()
assert API_KEY, "ERROR: OpenAI Key is missing"
client = OpenAI(
    api_key=API_KEY
    )

model = "gpt-3.5-turbo"

# %%
# Create your first prompt
text_prompt = " My foot hurts, what can be wrong?"

response = client.chat.completions.create(
  model=model,
  messages = [
      {"role":"system", "content":"I'm a doctor, specialist on surgery"},
      {"role":"user","content":text_prompt},])

response.choices[0].message.content
# Out:
# 'I am sorry to hear that your foot is hurting. Foot pain can be caused by a variety of conditions, including:\n- Plantar fasciitis: inflammation of the tissue on the bottom of your foot.\n- Achilles tendonitis: inflammation of the Achilles tendon.\n- Stress fractures: small cracks in the bones of the foot.\n- Bunions or other structural foot issues.\n- Arthritis: inflammation of the joints in the foot.\nIt is important to consult with a healthcare provider, like a podiatrist or orthopedic surgeon, who can examine your foot and provide a proper diagnosis and treatment plan.'
